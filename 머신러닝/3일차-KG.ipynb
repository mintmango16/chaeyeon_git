# %% [markdown]
# # 날짜 데이터 다루기

# %%
# 날짜의 종류
# date 2025-03-15

# datetime 2025-03-25 09:16:00 

# week mon, tue

# %%
all_list = []

all_list.append({'date' : '2025-03-10', 'week' : 'mon'})
all_list.append({'date' : '2025-03-11', 'week' : 'tue'})
all_list.append({'date' : '2025-03-12', 'week' : 'win'})

all_list
# Out:
# [{'date': '2025-03-10', 'week': 'mon'},
#  {'date': '2025-03-11', 'week': 'tue'},
#  {'date': '2025-03-12', 'week': 'win'}]

# %%
import pandas as pd

# %%
# series data fortmat -> DataFrame format 전환 가능
df = pd.DataFrame(all_list)

df
# Out:
#          date week
# 0  2025-03-10  mon
# 1  2025-03-11  tue
# 2  2025-03-12  win

# %% [markdown]
# # CSV (Comma Separated Value)
# - excel type -> text 을 excel 에서 취급할 수 있도록 지원
# - 처리 속도가 빠름
# - 확장자 .xlsx > xml 화 시킨 Excel 데이터 \취위급방법

# %%
df.to_csv('test.csv')

# %%
df2 = pd.read_csv('test.csv')
df2
# Out:
#    Unnamed: 0        date week
# 0           0  2025-03-10  mon
# 1           1  2025-03-11  tue
# 2           2  2025-03-12  win

# %%
df.to_csv('test.csv', index=False)
df2 = pd.read_csv('test.csv')
df2
# Out:
#          date week
# 0  2025-03-10  mon
# 1  2025-03-11  tue
# 2  2025-03-12  win

# %%
# 파일의 위치

import os
os.getcwd()   # Current Work Directory
# Out:
# 'D:\\python-workplace\\데이터분석2'

# %%
dir_path = './'
df = pd.read_csv(dir_path + 'train.csv')
df
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
set(df['season'])   # 봄 : 1, 여름 : 2, 가을: 3, 겨울:4
# Out:
# {1, 2, 3, 4}

# %%
set(df['holiday'])
# Out:
# {0, 1}

# %%
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df.tail()
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 10881  19.695        50    26.0027       7         329    336
# 10882  17.425        57    15.0013      10         231    241
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88

# %%
df.head(10)
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# 5  2011-01-01 05:00:00       1        0           0        2   9.84  12.880
# 6  2011-01-01 06:00:00       1        0           0        1   9.02  13.635
# 7  2011-01-01 07:00:00       1        0           0        1   8.20  12.880
# 8  2011-01-01 08:00:00       1        0           0        1   9.84  14.395
# 9  2011-01-01 09:00:00       1        0           0        1  13.12  17.425
#
#    humidity  windspeed  casual  registered  count
# 0        81     0.0000       3          13     16
# ...

# %%
df.shape   # 데이터 구조 (행, 열)
# Out:
# (10886, 12)

# %%
df.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
df.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %%
df.describe(include='all')
# Out:
#                    datetime        season       holiday    workingday  \
# count                 10886  10886.000000  10886.000000  10886.000000
# unique                10886           NaN           NaN           NaN
# top     2012-12-19 23:00:00           NaN           NaN           NaN
# freq                      1           NaN           NaN           NaN
# mean                    NaN      2.506614      0.028569      0.680875
# std                     NaN      1.116174      0.166599      0.466159
# min                     NaN      1.000000      0.000000      0.000000
# 25%                     NaN      2.000000      0.000000      0.000000
# 50%                     NaN      3.000000      0.000000      1.000000
# 75%                     NaN      4.000000      0.000000      1.000000
# max                     NaN      4.000000      1.000000      1.000000
#
#              weather         temp         atemp      humidity     windspeed  \
# ...

# %%
df['season'].describe()
# Out:
# count    10886.000000
# mean         2.506614
# std          1.116174
# min          1.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max          4.000000
# Name: season, dtype: float64

# %%
set(df['season'])  # 집합 요소 알아야 변경 가능
# Out:
# {1, 2, 3, 4}

# %%
df['season'].value_counts()
# Out:
# season
# 4    2734
# 2    2733
# 3    2733
# 1    2686
# Name: count, dtype: int64

# %%
df['weather'].value_counts()
# Out:
# weather
# 1    7192
# 2    2834
# 3     859
# 4       1
# Name: count, dtype: int64

# %%
# 상관 계수 (coefficient os correlation)
# 날씨에 따른 이용량 상관계수 분석
df[['weather','count']].corr() # 0 ~ 1 : 0.7 ~ 0.8
# Out:
#           weather     count
# weather  1.000000 -0.128655
# count   -0.128655  1.000000

# %% [markdown]
# # 데이터 분석 방법론
#
# - 체계화한 절차와 방법이 정리된 분석 방법록이 필요
# - 전통적인 데이터 분석 방법론 : KDD, CRISP-DM
# - CRISP-DM(Crose-Industry Standard Process - Data-Mining)
# - 가장 많이(분야, 산업군 막론하고) 사용되는 방법론

# %% [markdown]
# # Business Undestanding
#
# - 분석할 분야의 목적과 요구사항을 이해하고, 초기 프로젝트 계획을 수립하는 단계
# - 해당 분야의 종사사들이 원하는 방향
# - 분야나, 산업군 별로 관심사(KPI) 가 다름
# - 제조업 : 매출액 증대, 재구매율 증가, ....
# - 숙박업 : 예약 최소율 관리
# - 분석 방향성 및 목표 설정

# %% [markdown]
# # Data Understanding
#
# - 데이터를 수집하고, 데이터의 속성을 이해하기 위한 단계
# - 데이터 분석 기술, EDA, 데이터 품질 확인

# %% [markdown]
# # EDA(Exploratiry Data Analysis, 탐색적 데이터 분석)
#
# - 시각화를 통해 데이터 안의 유효한 패턴(인사이트)를 확인하는 단계
# - 수집한 데이터를 관찰하고 이해하는 과정
# - Business Understading 단계에서 설정한 방향성과 목표에 부합하면서 유효한 데이터 확인

# %% [markdown]
# # 데이터 품질
#
# - 결측치, 일관성, 형태, 정보 분석

# %% [markdown]
# # Data Preparation
#
# - 분석 기법에 적합한 데이터를 분석하는 단계
# - 모델링에 대비하는 단계
# - 알고리즘에 넣을 데이터를 적절하게 준비한는 단계
# - feature-label split
# - train-test split

# %% [markdown]
# # Machine Learning
# - 지도(Supervised) 학습
# - 비지도 학습

# %% [markdown]
# # Modeling
#
# - 다양한 Modeling 기법과 알고리즘을 선택하고, 사용되는 파라미터들을 최적화하는 단계
# - 모델의 성능을 평가하고, overfitting, underfitting 되었는지 확인
# - 세부적으로 Model Planning, Model Building을 구분 확인

# %% [markdown]
# # Palnning (분석 모형 기획)
#
# - 알고리증에 대한 후보 선정
# - 속도, 예측력, 해석력을 고려해서 후보군을 선정
# - 내부 계산이 복잡 할 수록 속도↓, 예측력↑, 해석력↓
# - 일반적으로 기술 통계분야의 알고리즘은 속도와 해석력 우수함

# %% [markdown]
# # Building
#
# - planning 단계에서 선택한 알고리즘에 학습용 데이터로 학습하고, 시험용 데이터 평가
# - 평가 시 관점에 따라 평가지표가 달라짐
# - case 1 ) 정답 : 1 , 예측: 2, 오차: 1
# - case 2 ) 정답 : 1001, 예측은 : 1002, 오차 : 1
# - 평가지표: 서로 다른 알고리즘 중 한 평가지표 기준으로 어떤 알고리즘의 정확도가 좋은가를 나타내는 척도

# %% [markdown]
# # Overfitting
# - train 데이터에만 최적화되는 것
# - test 데이터는 잘 구별하지 못하고 오히려 성능이 나빠지는 현상
# - 얼마만큼 학습 시키는 것이 좋은지 결정하는이 모델 설계에서 중요

# %% [markdown]
# # Evaluation
#
# - Modeling 결과가 프로젝트 목적에 부합하는지 평가
# - Modeling 과정, 분석 결과 등
# - Communicate Results
# - Excutive Summary, Technical Report 작성

# %% [markdown]
# # Develoyment
#
# - 완성된 모델을 실제 업무에 적용하기 위한 서비스 구현 단계
# - Operationaize
# - 모니터링과 모델의 유지보수 계획 마련

# %% [markdown]
# # CRISP_DM 기반의 데이터 분석
#
# - DataSet : 공공 저전거 이용량

# %% [markdown]
# # Business Understading
#
# - 공유 자전거 데이터 셋
# - 출처 : http://capitalbikeshare.com/
# - google 검색 > capital bikeshare dataset kaggle -> Bike Sharing Demand
# - 자전거라는 상품 대여
# - 대여되지 않는 자전거가 적을 수록 사업은 잘 된다고 판단
# - 수요량을 잘 이해하고 있다면 인력이나, 자원할당의 최적화 가능
# - 날씨, 요일, 시간에 따라 고객등의 서비스 이용량 증감을 분석

# %% [markdown]
# # Data Understanding
#
# - 날짜정보 (datetime, season, holiday, workingday)
# - 날씨정보 (weather, temp, atemp, humidity windspeed) - 파생변수
# - 이용량 (casul, resgistered, count)

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')
df
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# ...

# %%
df.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count'],
#       dtype='object')

# %%
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df.tail()
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count
# 10881  19.695        50    26.0027       7         329    336
# 10882  17.425        57    15.0013      10         231    241
# 10883  15.910        61    15.0013       4         164    168
# 10884  17.425        61     6.0032      12         117    129
# 10885  16.665        66     8.9981       4          84     88

# %%
df.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %%
df.shape
# Out:
# (10886, 12)

# %% [markdown]
# # Data Handling

# %%
df['datetime'].head()
# Out:
# 0    2011-01-01 00:00:00
# 1    2011-01-01 01:00:00
# 2    2011-01-01 02:00:00
# 3    2011-01-01 03:00:00
# 4    2011-01-01 04:00:00
# Name: datetime, dtype: object

# %%
sample = '2011-01-01 03:00:00'

# %%
year = sample.split(' ')[0].split('-')[0]
month = sample.split(' ')[0].split('-')[1]
day = sample.split(' ')[0].split('-')[2]

hour = sample.split(' ')[1].split(':')[0]
minute = sample.split(' ')[1].split(':')[1]
second = sample.split(' ')[1].split(':')[2]

print(year, month, day, hour, minute, second)
# Out:
# 2011 01 01 03 00 00

# %%
df['year'] = df['datetime'].apply( lambda x: int(x.split(' ')[0].split('-')[0]))
df['month'] = df['datetime'].apply( lambda x: int(x.split(' ')[0].split('-')[1]))
df['day'] = df['datetime'].apply( lambda x: int(x.split(' ')[0].split('-')[2]))

df['hour'] = df['datetime'].apply( lambda x: int(x.split(' ')[1].split(':')[0]))
df['minute'] = df['datetime'].apply( lambda x: int(x.split(' ')[1].split(':')[1]))
df['second'] = df['datetime'].apply( lambda x: int(x.split(' ')[1].split(':')[2]))

# %%
df
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0      2011-01-01 00:00:00       1        0           0        1   9.84
# 1      2011-01-01 01:00:00       1        0           0        1   9.02
# 2      2011-01-01 02:00:00       1        0           0        1   9.02
# 3      2011-01-01 03:00:00       1        0           0        1   9.84
# 4      2011-01-01 04:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  casual  registered  count  year  month  \
# ...

# %%
df.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count',
#        'year', 'month', 'day', 'hour', 'minute', 'second'],
#       dtype='object')

# %%
interested = ['year', 'month', 'day', 'hour', 'minute', 'second']
df[interested]
# Out:
#        year  month  day  hour  minute  second
# 0      2011      1    1     0       0       0
# 1      2011      1    1     1       0       0
# 2      2011      1    1     2       0       0
# 3      2011      1    1     3       0       0
# 4      2011      1    1     4       0       0
# ...     ...    ...  ...   ...     ...     ...
# 10881  2012     12   19    19       0       0
# 10882  2012     12   19    20       0       0
# 10883  2012     12   19    21       0       0
# 10884  2012     12   19    22       0       0
# 10885  2012     12   19    23       0       0
#
# [10886 rows x 6 columns]

# %%
sample = '2025-03-15 03:00:00'
type(sample)
# Out:
# str

# %%
parsed = pd.to_datetime(sample)
parsed
# Out:
# Timestamp('2025-03-15 03:00:00')

# %%
parsed.dayofweek   # 5 : 토  -> 0 ~ 6 (월, 화, 수, 목, 금, 토, 일)
# Out:
# 5

# %%
# datatiem열을 timestamp 타입으로 변환하여 요일을 숫자로 표현한 열 생성 
df['dayofweek'] = df['datetime'].apply(lambda x: pd.to_datetime(x).dayofweek)
df.columns
# Out:
# Index(['datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
#        'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count',
#        'year', 'month', 'day', 'hour', 'minute', 'second', 'dayofweek'],
#       dtype='object')

# %%
set(df['dayofweek']) # 월요일 ~일요일로 구성돠어있는 범주형 변수
# Out:
# {0, 1, 2, 3, 4, 5, 6}

# %%
set(df['weather'])
# Out:
# {1, 2, 3, 4}

# %%
set(df['season'])
# Out:
# {1, 2, 3, 4}

# %%
set(df['windspeed'])
# Out:
# {0.0,
#  6.0032,
#  7.0015,
#  8.9981,
#  11.0014,
#  12.998,
#  15.0013,
#  16.9979,
#  19.0012,
#  19.9995,
#  22.0028,
#  23.9994,
#  26.0027,
#  27.9993,
#  30.0026,
#  31.0009,
#  32.9975,
#  35.0008,
#  36.9974,
#  39.0007,
#  40.9973,
#  43.0006,
#  43.9989,
#  46.0022,
#  47.9988,
#  50.0021,
#  51.9987,
#  56.9969}

# %%
set(df['temp'])
# Out:
# {0.82,
#  1.64,
#  2.46,
#  3.28,
#  4.1,
#  4.92,
#  5.74,
#  6.56,
#  7.38,
#  8.2,
#  9.02,
#  9.84,
#  10.66,
#  11.48,
#  12.3,
#  13.12,
#  13.94,
#  14.76,
#  15.58,
#  16.4,
#  17.22,
#  18.04,
#  18.86,
#  19.68,
#  20.5,
#  21.32,
#  22.14,
#  22.96,
#  23.78,
#  24.6,
#  25.42,
#  26.24,
#  27.06,
#  27.88,
#  28.7,
#  29.52,
#  30.34,
#  31.16,
#  31.98,
#  32.8,
#  33.62,
#  34.44,
#  35.26,
#  36.08,
#  36.9,
#  37.72,
#  38.54,
#  39.36,
#  41.0}

# %%
interested = ['year', 'month', 'day', 'hour', 'minute', 'second', 'dayofweek',
'season', 'holiday', 'workingday', 'weather', 'temp',
'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count']

df[interested] #특정 열만 추출
# Out:
#        year  month  day  hour  minute  second  dayofweek  season  holiday  \
# 0      2011      1    1     0       0       0          5       1        0
# 1      2011      1    1     1       0       0          5       1        0
# 2      2011      1    1     2       0       0          5       1        0
# 3      2011      1    1     3       0       0          5       1        0
# 4      2011      1    1     4       0       0          5       1        0
# ...     ...    ...  ...   ...     ...     ...        ...     ...      ...
# 10881  2012     12   19    19       0       0          2       4        0
# 10882  2012     12   19    20       0       0          2       4        0
# 10883  2012     12   19    21       0       0          2       4        0
# 10884  2012     12   19    22       0       0          2       4        0
# 10885  2012     12   19    23       0       0          2       4        0
#
#        workingday  weather   temp   atemp  humidity  windspeed  casual  \
# ...

# %%
df[interested].to_csv('test1_modify.csv', index=False)

# %%
import pandas  as pd
df = pd.read_csv('test1_modify.csv')
df
# Out:
#        year  month  day  hour  minute  second  dayofweek  season  holiday  \
# 0      2011      1    1     0       0       0          5       1        0
# 1      2011      1    1     1       0       0          5       1        0
# 2      2011      1    1     2       0       0          5       1        0
# 3      2011      1    1     3       0       0          5       1        0
# 4      2011      1    1     4       0       0          5       1        0
# ...     ...    ...  ...   ...     ...     ...        ...     ...      ...
# 10881  2012     12   19    19       0       0          2       4        0
# 10882  2012     12   19    20       0       0          2       4        0
# 10883  2012     12   19    21       0       0          2       4        0
# 10884  2012     12   19    22       0       0          2       4        0
# 10885  2012     12   19    23       0       0          2       4        0
#
#        workingday  weather   temp   atemp  humidity  windspeed  casual  \
# ...

# %% [markdown]
# # Data Exploration
#
# - 방향성과 맞는 그래프 생성

# %%
import seaborn as sns

# %%
sns.scatterplot(data=df, x='registered', y='casual') #무슨기준으로 두 라인으로 나뉘는지 알수 없음
# Out:
# <Axes: xlabel='registered', ylabel='casual'>

# %%
sns.scatterplot(data=df, x='registered', y='casual', hue='season') 

# 색 지정을 통해 무슨 변수 기준으로 나뉘는지 탐색 : season은 아닌 것 같아 보임
# Out:
# <Axes: xlabel='registered', ylabel='casual'>

# %%
sns.scatterplot(data=df, x='registered', y='casual', # 이용량
                hue='workingday')

# 평일에는 등록회원이 많이 사용하고
# 휴일에는 비등록회원이 많이 사용함.
# 등혹/비등록 회원의 사용하는 빈도의 차이는 평일과 휴일이 명확하게 구분되는 것을 알수 있음

# 데이터를 표현, 해석하는 그림을 통해 데이터를 잘 표현하는 문장을 도출해랴 함.
# 그림을 해석하는 문장을 도ㅗ출해 낼수 있어야 하고, 그 문장의 의가미 있어야 함.
# Out:
# <Axes: xlabel='registered', ylabel='casual'>

# %%
#Q) lineplot을 활용해서 월별 등록/비등록 회원의 이용량 그래프 그려보아라.

sns.lineplot(data=df, x='month', y='casual')

#4~9월에 이용량이 높은 것을 확인할 수 있음
# Out:
# <Axes: xlabel='month', ylabel='casual'>

# %%
sns.lineplot(data=df, x='month', y='registered')

# 하반기에 등록이 많이 발생함
# Out:
# <Axes: xlabel='month', ylabel='registered'>

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

sns.lineplot(data=df, x='month', y='casual', ax=ax[0])
sns.lineplot(data=df, x='month', y='registered', ax=ax[1])
# Out:
# <Axes: xlabel='month', ylabel='registered'>

# %%
# Q) 사람의 행동 패턴에 가장 큰영향을 미칠만한 요소가 무엇일까 ?

fig, ax = plt.subplots(1, 2, figsize=(12, 5))

sns.lineplot(data=df, x='hour', y='casual', ax=ax[0])
sns.lineplot(data=df, x='hour', y='registered', ax=ax[1])

# 낮에 이용량이 많고 , 등록회원을 아침와 저녁에 많이 이용함 
# 등록회원의 경우 출퇴근용으로 사용하는 것으로 추측 가능
# Out:
# <Axes: xlabel='hour', ylabel='registered'>

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

sns.lineplot(data=df, x='hour', y='casual', hue='workingday', ax=ax[0])
sns.lineplot(data=df, x='hour', y='registered', hue='workingday', ax=ax[1])

#
# Out:
# <Axes: xlabel='hour', ylabel='registered'>

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

sns.pointplot(data=df, x='hour', y='casual', hue='dayofweek', ax=ax[0])
sns.pointplot(data=df, x='hour', y='registered', hue='dayofweek', ax=ax[1])
# Out:
# <Axes: xlabel='hour', ylabel='registered'>

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

sns.pointplot(data=df, x='windspeed', y='casual', hue='workingday', ax=ax[0])
sns.pointplot(data=df, x='windspeed', y='registered', hue='workingday', ax=ax[1])

# 비등록회원은 바람 세기가 증가하면 이용률이 급감하는 반면 
# 평일에는 바람세가가 증가해도 이용률에 큰 차이가 없음

# 휴일에는 바람 세기가 증가할수 록 이용률이 급감
# Out:
# <Axes: xlabel='windspeed', ylabel='registered'>

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

sns.pointplot(data=df, x='dayofweek', y='casual', hue='workingday', ax=ax[0])
sns.pointplot(data=df, x='dayofweek', y='registered', hue='workingday', ax=ax[1])
# Out:
# <Axes: xlabel='dayofweek', ylabel='registered'>

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

sns.pointplot(data=df, x='humidity', y='casual', hue='workingday', ax=ax[0])
sns.pointplot(data=df, x='humidity', y='registered', hue='workingday', ax=ax[1])
# Out:
# <Axes: xlabel='humidity', ylabel='registered'>

# %%
datetime', 'season', 'holiday', 'workingday', 'weather', 'temp',
       'atemp', 'humidity', 'windspeed', 'casual', 'registered', 'count',
       'year', 'month', 'day', 'hour', 'minute', 'second', 'dayofweek'],
      dtype='object')

# %%
#체감온도에 따른 등록/비등록 회원 이용률
fig, ax = plt.subplots(2, 1, figsize=(12, 10))

sns.lineplot(data=df, x='atemp', y='casual', hue='workingday', ax=ax[0])
sns.lineplot(data=df, x='atemp', y='registered', hue='workingday', ax=ax[1])
# Out:
# <Axes: xlabel='atemp', ylabel='registered'>

# %%
df.describe()
# Out:
#                year         month           day          hour   minute  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.0
# mean    2011.501929      6.521495      9.992559     11.541613      0.0
# std        0.500019      3.444373      5.476608      6.915838      0.0
# min     2011.000000      1.000000      1.000000      0.000000      0.0
# 25%     2011.000000      4.000000      5.000000      6.000000      0.0
# 50%     2012.000000      7.000000     10.000000     12.000000      0.0
# 75%     2012.000000     10.000000     15.000000     18.000000      0.0
# max     2012.000000     12.000000     19.000000     23.000000      0.0
#
#         second     dayofweek        season       holiday    workingday  \
# count  10886.0  10886.000000  10886.000000  10886.000000  10886.000000
# mean       0.0      3.013963      2.506614      0.028569      0.680875
# std        0.0      2.004585      1.116174      0.166599      0.466159
# ...

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))
sns.pointplot( x= "season",y = "casual" ,hue = "workingday", data = df,ax= ax[0])
sns.pointplot( x= "season", y = "registered",hue = "workingday", data = df,ax= ax[1])
# Out:
# <Axes: xlabel='season', ylabel='registered'>

# %% [markdown]
# # Data Preparation

# %%
df.columns
# Out:
# Index(['year', 'month', 'day', 'hour', 'minute', 'second', 'dayofweek',
#        'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp',
#        'humidity', 'windspeed', 'casual', 'registered', 'count'],
#       dtype='object')

# %%
# feature - label split 
features = ['year', 'month', 'day', 'hour', 'dayofweek',
       'season', 'holiday', 'workingday', 'weather', 'temp', 'atemp',
       'humidity', 'windspeed']
label = 'count'

# %%
df.shape
# Out:
# (10886, 18)

# %%
# tarin - test split 1- 8:2, 2 - 7:3 (american 7.5 : 2.5 )

train, test = df[0::2], df[1::2]   # 5:5

train, test = train.reset_index(), test.reset_index()

# %%
test.shape
# Out:
# (5443, 19)

# %%
train.shape
# Out:
# (5443, 19)

# %%
X_train, y_train = train[features], train[label]
X_test, y_test = test[features], test[label]

# %%
print(X_train.shape, y_train.shape)
# Out:
# (5443, 13) (5443,)

# %%
print(X_test.shape, y_test.shape)
# Out:
# (5443, 13) (5443,)

# %%
X_train
# Out:
#       year  month  day  hour  dayofweek  season  holiday  workingday  weather  \
# 0     2011      1    1     0          5       1        0           0        1
# 1     2011      1    1     2          5       1        0           0        1
# 2     2011      1    1     4          5       1        0           0        1
# 3     2011      1    1     6          5       1        0           0        1
# 4     2011      1    1     8          5       1        0           0        1
# ...    ...    ...  ...   ...        ...     ...      ...         ...      ...
# 5438  2012     12   19    14          2       4        0           1        1
# 5439  2012     12   19    16          2       4        0           1        1
# 5440  2012     12   19    18          2       4        0           1        1
# 5441  2012     12   19    20          2       4        0           1        1
# 5442  2012     12   19    22          2       4        0           1        1
#
# ...

# %% [markdown]
# # Modelling - 속도, 예측력, 해석력 -- trade off
# - Planning, Building

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
model = RandomForestRegressor()

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
model.score(X_test, y_test)
# Out:
# 0.9230303030135867

# %%
model.score(X_train, y_train)
# Out:
# 0.9918896633085078

# %% [markdown]
# # 회귀 모델
# - 회귀(reggression): 두 변수(column, Target) 사이의 상관관계를 분석하는 방법
# - 임의의 어떤 숫자(역속적인 값: 가격, 매출, 주가, ....)를 예측하는 문제
# - 알고리즘: k-최근접 이웃 회귀, 선형(Liner) 회귀, 다중회귀 등

# %% [markdown]
# # Overfitting
# - 샘플에 모델이 너무 과하게 적합되어 있는 상태

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model_dt = DecisionTreeRegressor()
model_dt.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
model_dt.score(X_test, y_test)
# Out:
# 0.8579091625363324

# %%
# 과적합 발생 - 알고리증의 점수 예시

model_dt.score(X_train, y_train)

# 일반화(Generalization) 실패
# Decision Tree -> train 데이터셋을 100% 외우고 있음.
# Out:
# 1.0

# %% [markdown]
# # 다양한 회귀문제 평가 지표
# - R(Root), M(Mean), S(Squard), P(Percentile), A(Absolute), E(Error)
# - MAE, MSE, MAPE, RMSE, RMSLE

# %%
import numpy as np

# %%
# 2 - 1 = 1
# 1002 - 1001 = 1

err1 = np.log(2) - np.log(1)
err2 = np.log(1002) - np.log(1001)

print(err1, err2)

# 작은 값들끼리의 차이와
# 큰 값들끼리의 차이에 차등을 두기위해서 log() 함수를 사용
# Out:
# 0.6931471805599453 0.0009985023295895346

# %% [markdown]
# # 평가지표의 값이 높고 낮음의 의미를 시각화

# %%
model = RandomForestRegressor()
model.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
model.predict(X_test)
# Out:
# array([ 22.62,  15.31,   4.21, ..., 410.4 , 206.29, 133.79], shape=(5443,))

# %%
for_plot = pd.DataFrame()
for_plot['train_predict'] = model.predict(X_train)
for_plot['train_actual'] = y_train
for_plot['test_predict'] = model.predict(X_test)
for_plot['test_actual'] = y_test
for_plot
# Out:
#       train_predict  train_actual  test_predict  test_actual
# 0             22.17            16         22.62           40
# 1             27.29            32         15.31           13
# 2              2.88             1          4.21            1
# 3              3.45             2         30.48            3
# 4             25.36             8         53.82           14
# ...             ...           ...           ...          ...
# 5438         220.57           218        237.24          237
# 5439         341.94           334        580.19          562
# 5440         556.53           569        410.40          336
# 5441         256.11           241        206.29          168
# 5442         131.57           129        133.79           88
#
# [5443 rows x 4 columns]

# %%
for_plot_dt = pd.DataFrame()
for_plot_dt['train_predict'] = model_dt.predict(X_train)
for_plot_dt['train_actual'] = y_train
for_plot_dt['test_predict'] = model_dt.predict(X_test)
for_plot_dt['test_actual'] = y_test
for_plot_dt
# Out:
#       train_predict  train_actual  test_predict  test_actual
# 0              16.0            16          16.0           40
# 1              32.0            32          18.0           13
# 2               1.0             1           2.0            1
# 3               2.0             2           8.0            3
# 4               8.0             8          74.0           14
# ...             ...           ...           ...          ...
# 5438          218.0           218         218.0          237
# 5439          334.0           334         517.0          562
# 5440          569.0           569         371.0          336
# 5441          241.0           241         165.0          168
# 5442          129.0           129         129.0           88
#
# [5443 rows x 4 columns]

# %%
import seaborn as sns
print(model.score(X_train, y_train))
sns.scatterplot(data=for_plot, x='train_predict', y='train_actual')
# Out:
# 0.9919082736026708
# <Axes: xlabel='train_predict', ylabel='train_actual'>

# %%
import seaborn as sns
print(model.score(X_test, y_test))
sns.scatterplot(data=for_plot, x='test_predict', y='test_actual')
# Out:
# 0.9253056924194443
# <Axes: xlabel='test_predict', ylabel='test_actual'>

# %%
import seaborn as sns
print(model_dt.score(X_train, y_train))
sns.scatterplot(data=for_plot_dt, x='train_predict', y='train_actual')
# Out:
# 1.0
# <Axes: xlabel='train_predict', ylabel='train_actual'>

# %%
import seaborn as sns
print(model_dt.score(X_test, y_test))
sns.scatterplot(data=for_plot_dt, x='test_predict', y='test_actual')
# Out:
# 0.8579091625363324
# <Axes: xlabel='test_predict', ylabel='test_actual'>

# %%
import matplotlib.pyplot as plt

fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 12))
sns.scatterplot(data=for_plot, x='train_predict', y='train_actual', ax=ax1)
sns.scatterplot(data=for_plot, x='test_predict', y='test_actual', ax=ax2)
sns.scatterplot(data=for_plot_dt, x='train_predict', y='train_actual', ax=ax3)
sns.scatterplot(data=for_plot_dt, x='test_predict', y='test_actual', ax=ax4)
# Out:
# <Axes: xlabel='test_predict', ylabel='test_actual'>

# %% [markdown]
# ---
