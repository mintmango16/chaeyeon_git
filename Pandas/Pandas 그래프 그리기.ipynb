# %%
# 그래프 반복 호출로 생기는 경고 감추기
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 04-1 데이터 시각화란?

# %%
import seaborn as sns

anscombe = sns.load_dataset("anscombe")
print(anscombe)
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# 37      IV   8.0   8.47
# 38      IV   8.0   7.04
# 39      IV   8.0   5.25
# 40      IV  19.0  12.50
# 41      IV   8.0   5.56
# 42      IV   8.0   7.91
# 43      IV   8.0   6.89

# %% [markdown]
# ## 04-2 matplotlib 라이브러리란?

# %%
import matplotlib.pyplot as plt

# %%
dataset_1 = anscombe[anscombe['dataset'] == 'I']

plt.plot(dataset_1['x'], dataset_1['y'])

plt.show()

# %%
plt.plot(dataset_1['x'], dataset_1['y'], 
         'bo') # 점 그래프
plt.show()

# %%
dataset_2 = anscombe[anscombe['dataset'] == 'II']
dataset_3 = anscombe[anscombe['dataset'] == 'III']
dataset_4 = anscombe[anscombe['dataset'] == 'IV']

# %% [markdown]
# ### 그림 영역과 하위 그래프 이해하기

# %% [markdown]
# #### [실습] 한 번에 4개의 그래프 그리기

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2, 2, 1) #2행 2열의 첫번째 그래프
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)

plt.show()

# %%
fig = plt.figure() #그래프를 그릴 도화지 
axes1 = fig.add_subplot(2, 2, 1)
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)

axes1.plot(dataset_1['x'], dataset_1['y'], 'o')
axes2.plot(dataset_2['x'], dataset_2['y'], 'o')
axes3.plot(dataset_3['x'], dataset_3['y'], 'o')
axes4.plot(dataset_4['x'], dataset_4['y'], 'o')

plt.show()

# %%
fig = plt.figure()
axes1 = fig.add_subplot(2, 2, 1)
axes2 = fig.add_subplot(2, 2, 2)
axes3 = fig.add_subplot(2, 2, 3)
axes4 = fig.add_subplot(2, 2, 4)

axes1.plot(dataset_1['x'], dataset_1['y'], 'o') #분산된 산점도
axes2.plot(dataset_2['x'], dataset_2['y'], 'o') # 이차원 곡선 형태를 이루는 산점도
axes3.plot(dataset_3['x'], dataset_3['y'], 'o') #이상치가 있는 산점도
axes4.plot(dataset_4['x'], dataset_4['y'], 'o') #한곳에 집중된 산점도 -> 로그함수 이용하여 다시 그려야함

axes1.set_title("dataset_1")
axes2.set_title("dataset_2")
axes3.set_title("dataset_3")
axes4.set_title("dataset_4")

fig.suptitle("Anscombe Data") # 전체 제목

fig.set_tight_layout(True) #위에 제목을 입력할 공간 만들기

plt.show()

# %%
#subplot 한번에 지정
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2, ncols=2) 
fig.set_size_inches(8, 6) #넓이, 높이 순 그래프 크기 설정

ax1.plot(dataset_1['x'], dataset_1['y'], 'o')
ax2.plot(dataset_2['x'], dataset_2['y'], 'o')
ax3.plot(dataset_3['x'], dataset_3['y'], 'o')
ax4.plot(dataset_4['x'], dataset_4['y'], 'o')

plt.show()

# %% [markdown]
# ## 04-3 matplotlib으로 그래프 그리기

# %%
tips = sns.load_dataset("tips") #sns에 내장된 tips 데이터셋 로드
print(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ### 일변량 그래프 그리기

# %% [markdown]
# #### [실습] 히스토그램 그리기

# %%
# 값을 일정한 분포로 묶어서 분포를 나타내는 그래프
fig = plt.figure()

axes1 = fig.add_subplot(1, 1, 1)

axes1.hist(data=tips, x='total_bill',
           bins=10) # x축의 구간 갯수  = 10 = 히스토그램의 막대 개수, 최솟값과 최댓값을 기준으로 나눔

axes1.set_title('Histogram of Total Bill')
axes1.set_xlabel('Total Bill') #x축 제목
axes1.set_ylabel('Frequency') #y축 제목

plt.show()

# %% [markdown]
# ### 이변량(변수 2개) 그래프 그리기

# %% [markdown]
# #### [실습] 산점도 그래프 그리기

# %%
scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1, 1, 1)

axes1.scatter(x = tips['total_bill'], y = tips['tip'])
#연속 변수 사이의 관계를 나타내는 그래프

axes1.set_title('Scatterplot of Total Bill vs Tip')
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')

plt.show()

# %% [markdown]
# #### [실습] 박스 그래프 그리기

# %%
#이산 변수와 연속변수 사이의 관계 표현

boxplot = plt.figure()
axes1 = boxplot.add_subplot(1, 1, 1)

axes1.boxplot(
    x=[tips[tips['sex'] == 'Female']['tip'],
       tips[tips['sex'] == 'Male']['tip']],# x에 리스트로 데이터 전달
    labels=['Female', 'Male']
)

axes1.set_xlabel('Sex')
axes1.set_ylabel('Tip')
axes1.set_title('Boxplot of Tips by Sex')

plt.show()

# %% [markdown]
# ### 다변량(3개 이상) 그래프 그리기

# %% [markdown]
# #### [실습] 변수가 여러 개인 그래프 그리기

# %%
colors = {"Female": "#AFEEEE", "Male": "#66CDAA"} #성별에 따른 RGB 설정 

scatter_plot = plt.figure()
axes1 = scatter_plot.add_subplot(1, 1, 1)

axes1.scatter(data=tips,
              x='total_bill',
              y='tip',
              s=tips['size']**2*10, #점의 크기 지정
              c=tips['sex'].map(colors), #색상 지정 : key면 value로 반환
              alpha=0.5) #산점도

axes1.set_title('Colored by Sex and Sized by Size') #그래프 소제목
axes1.set_xlabel('Total Bill')
axes1.set_ylabel('Tip')

scatter_plot.suptitle('Total Bill vs Tip')

plt.show()

# %% [markdown]
# ## 04-4 seaborn으로 그래프 그리기

# %%
import seaborn as sns
tips = sns.load_dataset("tips")

# %%
sns.set_context("paper")

# %% [markdown]
# ### 다양한 그래프 그려 보기

# %% [markdown]
# #### [실습] 일변량 그래프 그리기

# %% [markdown]
# ##### 1. 히스토그램 그리기

# %%
hist, ax = plt.subplots()

sns.histplot(data=tips, x='total_bill', ax=ax, stat = "count")
ax.set_title('Total Bill Histogram')
plt.show()

# %% [markdown]
# ##### 2. 밀도분포 그래프 그리기

# %%
# kdeplot : 정규분포 곡선을 그리는 곡선
den, ax = plt.subplots()

sns.kdeplot(data=tips, x='total_bill', ax=ax)

ax.set_title('Total Bill Density')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Unit Probability')

plt.show()

# %% [markdown]
# ##### 3. 러그 그래프 그리기

# %%
# rugplot : x축 쪽에 데이터 밀집도를 나타내줌
rug, ax = plt.subplots()

sns.rugplot(data=tips, x='total_bill', ax=ax)
sns.histplot(data=tips, x='total_bill', ax=ax)

ax.set_title('Rug Plot and Histogram of Total Bill')

plt.show()

# %% [markdown]
# ##### 4. 분포 그래프 그리기

# %%
fig = sns.displot(data=tips, x='total_bill', kde=True, rug=True) #한꺼번에 그리기

fig.set_axis_labels(x_var='Total Bill', y_var='Count') #축 제목 한줄로 지정
fig.figure.suptitle('Distribution of Total Bill')

plt.show()

# %% [markdown]
# ##### 5. 막대그래프 그리기

# %%
count, ax = plt.subplots()

sns.countplot(data=tips, x='day', palette='viridis', ax=ax)

ax.set_title('Count of days')
ax.set_xlabel('Day of the Week')
ax.set_ylabel('Frequency')

plt.show()

# %% [markdown]
# ### 이변량 그래프 그리기

# %% [markdown]
# #### [실습] 이변량 그래프 그리기

# %% [markdown]
# ##### 1. 산점도 그래프 그리기 ①

# %%
scatter, ax = plt.subplots()

sns.scatterplot(data=tips, x='total_bill', y='tip', ax=ax)

ax.set_title('Scatter Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')

plt.show()

# %% [markdown]
# ##### 2. 산점도 그래프 그리기 ②

# %%
reg, ax = plt.subplots()

sns.regplot(data=tips, x='total_bill', y='tip', ax=ax) 
# 추세선에서 기울기가 흔들리는 정도를 regplot으로 표시

ax.set_title('Regression Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')

plt.show()

# %%
fig = sns.lmplot(data=tips, x='total_bill', y='tip')
#lm으로도 추세선 표시 가능

print(type(fig))
plt.show()
# Out:
# <class 'seaborn.axisgrid.FacetGrid'>

# %% [markdown]
# ##### 3. 조인트 그래프 그리기

# %%
joint = sns.jointplot(data=tips, x='total_bill', y='tip')
joint.set_axis_labels(xlabel='Total Bill', ylabel='Tip')

joint.figure.suptitle('Joint Plot of Total Bill and Tip', y=1.03) #그래프 제목 설정

plt.show()

# %% [markdown]
# ##### 4. 육각 그래프 그리기

# %%
hexbin = sns.jointplot(data=tips, x="total_bill", y="tip", 
                       kind="hex") #육각그래프 그릴 때 지정 필수

hexbin.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
hexbin.figure.suptitle('Hexbin Joint Plot of Total Bill and Tip', y=1.03)

plt.show()

# %% [markdown]
# ##### 5. 2차원 밀도분포 그래프 그리기

# %%
#kdeplot
kde, ax = plt.subplots()

#히스토그램을 위에서 바라본 시점 : 등분산도
sns.kdeplot(data=tips, x="total_bill", y="tip", fill=True, ax=ax)

ax.set_title('Kernel Density Plot of Total Bill and Tip')
ax.set_xlabel('Total Bill')
ax.set_ylabel('Tip')

plt.show()

# %%
kde2d = sns.jointplot(data=tips, x="total_bill", y="tip",
                      kind="kde") #색 구분 대신 선으로 구분

kde2d.set_axis_labels(xlabel='Total Bill', ylabel='Tip')
kde2d.figure.suptitle('Hexbin Joint Plot of Total Bill and Tip', y=1.03)

plt.show()

# %% [markdown]
# ##### 6. 막대그래프 그리기

# %%
import numpy as np

bar, ax = plt.subplots()

sns.barplot(data=tips, x="time", y="total_bill", estimator=np.mean, ax=ax)

ax.set_title('Bar Plot of Average Total Bill for Time of Day')
ax.set_xlabel('Time of Day')
ax.set_ylabel('Average Total Bill')

plt.show()

# %% [markdown]
# ##### 7. 박스 그래프 그리기

# %%
box, ax = plt.subplots()

sns.boxplot(data=tips, x='time', y='total_bill', ax=ax)

ax.set_title('Bar Plot of Total Bill for Time of Day')
ax.set_xlabel('Time of Day')
ax.set_ylabel('Total Bill')

plt.show()

# %% [markdown]
# ##### 8. 바이올린 그래프 그리기

# %%
violin, ax = plt.subplots()

sns.violinplot(data=tips, x='time', y='total_bill', ax=ax)

ax.set_title('Violin plot of total bill by time of day')
ax.set_xlabel('Time of day')
ax.set_ylabel('Total Bill')

plt.show()

# %%
box_violin, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)

sns.boxplot(data=tips, x='time', y='total_bill', ax=ax1)
sns.violinplot(data=tips, x='time', y='total_bill', ax=ax2)

ax1.set_title('Box Plot')
ax1.set_xlabel('Time of Day')
ax1.set_ylabel('Total Bill')

ax2.set_title('Violin plot')
ax2.set_xlabel('Time of day')
ax2.set_ylabel('Total Bill')

box_violin.suptitle("Comparison of Box Plot with Violin Plot")

box_violin.set_tight_layout(True) #전체 제목을 표시하기 위한 공간 만들기

plt.show()

# %% [markdown]
# ##### 9. 관계 그래프 그리기 ①

# %%
fig = sns.pairplot(data=tips)
# 그래프의 관계도 생성

fig.figure.suptitle('Pairwise Relationships of the Tips Data', y=1.03)

plt.show()

# %% [markdown]
# ##### 10. 관계 그래프 그리기 ②

# %%
pair_grid = sns.PairGrid(tips, diag_sharey=False)

pair_grid = pair_grid.map_upper(sns.regplot)
pair_grid = pair_grid.map_lower(sns.kdeplot)
pair_grid = pair_grid.map_diag(sns.histplot)
#3개의 그래프 합치기
plt.show()

# %% [markdown]
# #### [실습] 다변량 그래프 그리기

# %% [markdown]
# ##### 1. 그래프에 색상 입히기

# %%
violin, ax = plt.subplots()

sns.violinplot(data=tips,
               x="time",
               y="total_bill",
               hue="smoker",
               split=True, #색깔 구분
               palette="viridis",
               ax=ax)

plt.show()

# %%
scatter = sns.lmplot(data=tips,
                     x="total_bill",
                     y="tip",
                     hue="smoker", #색상 구분할 데이터
                     fit_reg=False,
                     palette="viridis")

plt.show()

# %%
fig = sns.pairplot(tips, hue="time", palette="viridis")

plt.show()

# %% [markdown]
# ##### 2. 그래프 크기와 모양 조절하기

# %%
fig, ax = plt.subplots()

sns.scatterplot(data=tips,
                x="total_bill",
                y="tip",
                hue="time",
                size="size",
                palette="viridis",
                ax=ax)

plt.show()

# %% [markdown]
# #### [실습] 그래프 나눠 그리기

# %% [markdown]
# ##### 1. 1개의 범주형 변수로 그래프 나누기

# %%
anscombe = sns.load_dataset("anscombe")

# %%
anscombe_plot = sns.relplot(data=anscombe,
                            x="x",
                            y="y",
                            kind="scatter",
                            col="dataset",
                            col_wrap=2, #한 행에 그래프 2개씩 
                            height=2,
                            aspect=1.6)

anscombe_plot.figure.set_tight_layout(True)

plt.show()

# %% [markdown]
# ##### 2. 여러 개의 범주형 변수로 그래프 나누기

# %%
colors = {
    "Yes": "#f1a340", # 주황색
    "No" : "#998ec3", # 보라색
}

facet2 = sns.relplot(data=tips,
                     x="total_bill",
                     y="tip",
                     hue="smoker", #색으로 구분
                     style="sex", #크기로 구분
                     kind="scatter",
                     col="day", #열은 데이로 구분
                     row="time", #행은 시간으로 구분
                     palette=colors,
                     height=1.7)

# 여기서부터는 그래프를 꾸미는 코드입니다.
# 나눠진 각 그래프에 제목을 붙입니다.
facet2.set_titles(row_template="{row_name}", col_template="{col_name}")

# 그래프에 범주를 추가하는 코드입니다.
sns.move_legend(facet2,
                loc="lower center",
                bbox_to_anchor=(0.5, 1),
                ncol=2,         # 범주의 열 개수
                title=None,     # 범주 제목
                frameon=False)  # 범주 테두리를 숨깁니다.

facet2.figure.set_tight_layout(True)

plt.show()

# %% [markdown]
# ##### 3. FacetGrid 객체로 그래프 직접 나누기

# %%
facet = sns.FacetGrid(tips, col='time')

facet.map(sns.histplot, 'total_bill')
plt.show()

# %%
facet = sns.FacetGrid(tips, 
                      col='day', 
                      col_wrap=2, 
                      hue='sex', 
                      palette="viridis")

facet.map(plt.scatter, 'total_bill', 'tip')
facet.add_legend()
plt.show()

# %%
facet = sns.FacetGrid(tips, 
                      col='time', 
                      row='smoker', 
                      hue='sex', 
                      palette="viridis")

facet.map(plt.scatter, 'total_bill', 'tip')
plt.show()

# %%
facet = sns.catplot(x="day",
                    y="total_bill",
                    hue="sex",
                    data=tips,
                    row="smoker",
                    col="time",
                    kind="violin",
                    height=3)
plt.show()

# %% [markdown]
# ### seaborn 스타일 알아보기

# %% [markdown]
# #### [실습] 스타일 알아보기

# %%
fig, ax = plt.subplots()
sns.violinplot(data=tips, 
               x="time", 
               y="total_bill", 
               hue="sex", 
               split=True, 
               ax=ax)

plt.show()

# %%
# 전체 스타일을 darkgrid로 변경하고 싶다면 아래 코드를 주석 해제하고 실행하세요.
# sns.set_style("darkgrid")
# fig, ax = plt.subplots()
# sns.violinplot(data=tips, 
#                x=”time”, 
#                y="total_bill", 
#                hue="sex", 
#                split=True, 
#                ax=ax)

# 특정 그래프만 다른 스타일로 그리는 코드입니다.
with sns.axes_style("darkgrid"):
    fig, ax = plt.subplots()
    sns.violinplot(data=tips, 
                   x="time", 
                   y="total_bill", 
                   hue="sex", 
                   split=True,
                   ax=ax)
    
plt.show()

# %%
seaborn_styles = ["darkgrid", "whitegrid", "dark", "white", "ticks"]

fig = plt.figure()
for idx, style in enumerate(seaborn_styles):
    plot_position = idx + 1
    with sns.axes_style(style):
        ax = fig.add_subplot(2, 3, plot_position)
        violin = sns.violinplot(data=tips, x="time", y="total_bill", ax=ax)
        violin.set_title(style)

fig.set_tight_layout(True)
plt.show()

# %% [markdown]
# #### [Do It! 실습] 그래프 컨텍스트 설정하기

# %%
import pandas as pd

contexts = pd.DataFrame({
    "paper": sns.plotting_context("paper"),
    "notebook": sns.plotting_context("notebook"),
    "talk": sns.plotting_context("talk"),
    "poster": sns.plotting_context("poster"),
})
print(contexts)
# Out:
#                        paper  notebook    talk  poster
# axes.linewidth           1.0      1.25   1.875     2.5
# grid.linewidth           0.8      1.00   1.500     2.0
# lines.linewidth          1.2      1.50   2.250     3.0
# lines.markersize         4.8      6.00   9.000    12.0
# patch.linewidth          0.8      1.00   1.500     2.0
# xtick.major.width        1.0      1.25   1.875     2.5
# ytick.major.width        1.0      1.25   1.875     2.5
# xtick.minor.width        0.8      1.00   1.500     2.0
# ytick.minor.width        0.8      1.00   1.500     2.0
# xtick.major.size         4.8      6.00   9.000    12.0
# ytick.major.size         4.8      6.00   9.000    12.0
# xtick.minor.size         3.2      4.00   6.000     8.0
# ytick.minor.size         3.2      4.00   6.000     8.0
# font.size                9.6     12.00  18.000    24.0
# axes.labelsize           9.6     12.00  18.000    24.0
# axes.titlesize           9.6     12.00  18.000    24.0
# xtick.labelsize          8.8     11.00  16.500    22.0
# ytick.labelsize          8.8     11.00  16.500    22.0
# legend.fontsize          8.8     11.00  16.500    22.0
# legend.title_fontsize    9.6     12.00  18.000    24.0

# %%
context_styles = contexts.columns

fig = plt.figure()
for idx, context in enumerate(context_styles):
    plot_position = idx + 1
    with sns.plotting_context(context):
        ax = fig.add_subplot(2, 2, plot_position)
        violin = sns.violinplot(data=tips, x="time", y="total_bill", ax=ax)
        violin.set_title(context)
fig.set_tight_layout(True)
plt.show()

# %% [markdown]
# ### seaborn 공식 문서를 읽는 방법

# %% [markdown]
# ##### matplotlib의 Axes 객체

# %%
box_violin, (ax1, ax2) = plt.subplots(nrows=1, ncols=2)

sns.boxplot(data=tips, x='time', y='total_bill', ax=ax1)
sns.violinplot(data=tips, x='time', y='total_bill', ax=ax2)

ax1.set_title('Box Plot')
ax1.set_xlabel('Time of Day')
ax1.set_ylabel('Total Bill')

ax2.set_title('Violin plot')
ax2.set_xlabel('Time of day')
ax2.set_ylabel('Total Bill')

box_violin.suptitle("Comparison of Box Plot with Violin Plot")

box_violin.set_tight_layout(True)
plt.show()

# %%
print(type(ax2))
# Out:
# <class 'matplotlib.axes._axes.Axes'>

# %% [markdown]
# ##### matplotlib의 Figure 객체

# %%
print(type(box_violin))
# Out:
# <class 'matplotlib.figure.Figure'>

# %% [markdown]
# ##### seaborn의 객체

# %%
fig = sns.pairplot(data=tips)
fig.figure.suptitle('Pairwise Relationships of the Tips Data', y=1.03)
plt.show()

# %%
print(type(fig))
# Out:
# <class 'seaborn.axisgrid.PairGrid'>

# %% [markdown]
# ## 04-5 판다스로 그래프 그리기

# %% [markdown]
# #### [Do It! 실습] 판다스로 다양한 그래프 그리기

# %% [markdown]
# ##### 1. 히스토그램 그리기

# %%
fig, ax = plt.subplots()
tips['total_bill'].plot.hist(ax=ax)
plt.show()

# %%
fig, ax = plt.subplots()
tips[['total_bill', 'tip']].plot.hist(alpha=0.5, bins=20, ax=ax)
plt.show()

# %% [markdown]
# ##### 2. 밀도분포 그래프 그리기

# %%
fig, ax = plt.subplots()
tips['tip'].plot.kde(ax=ax)
plt.show()

# %% [markdown]
# ##### 3. 산점도 그리기

# %%
fig, ax = plt.subplots()
tips.plot.scatter(x='total_bill', y='tip', ax=ax)
plt.show()

# %% [markdown]
# ##### 4. 육각 그래프 그리기

# %%
fig, ax = plt.subplots()
tips.plot.hexbin(x='total_bill', y='tip', ax=ax)
plt.show()

# %%
fig, ax = plt.subplots()
tips.plot.hexbin(x='total_bill', y='tip', gridsize=10, ax=ax)
plt.show()

# %% [markdown]
# ##### 5. 박스 그래프 그리기

# %%
fig, ax = plt.subplots()
tips.plot.box(ax=ax)
plt.show()
